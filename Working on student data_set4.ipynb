# %% [markdown]
# ## objectives:
# 1.plot marks graph
#
# 2.plot scatter of marks and number of courses
#
# 3.find number of courses which are only == 3
#
# 4.highest number courses, highest time_study, highest marks
#
# 5.number of courses ==3 and greater there marks greater than 10
#
# 6.split
#
# 7.train
#
# 8.shape of X_train,X_test,y_train,y_test
#
# 9.use StandardScaler
#
# 10.after SandardScaler check X_train shape should be 80 x 2
#
# 11.check X_train is in array
#
# 12.apply LinearRegression
#
# 13.fit
#
# 14.predict
#
# 15.check model score
#
# 16.also check r square of this model (optional)
#
# 17.Mean Square Error
#
# 18.Root mean Square error

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.metrics import mean_squared_error
df = pd.read_csv(r"X:\sir ismail AI course\jupyter data sice\dataset\Student_Marks.csv")
df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
plt.plot(df["Marks"])

# %%
plt.scatter(df["Marks"],df["number_courses"])
plt.xlabel("Marks")
plt.ylabel("cources")
plt.show()

# %%
df[df["number_courses"] == 3]
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 6                3       6.063  29.889
# 9                3       6.173  30.862
# 10               3       7.353  42.036
# 13               3       4.274  17.672
# 14               3       2.908  11.397
# 25               3       1.407   6.623
# 31               3       1.923   8.100
# 34               3       4.083  17.171
# 35               3       7.543  43.978
# 45               3       2.061   8.924
# 48               3       5.635  26.882
# 58               3       6.198  31.236
# 63               3       4.869  21.379
# 67               3       0.550   6.185
# 72               3       4.633  20.398
# 73               3       1.629   7.014
# 75               3       0.803   6.217
# 79               3       0.805   6.349
# 87               3       1.033   6.053
# 96               3       0.301   5.609
# 99               3       6.335  32.357

# %%
df[df["time_study"] == max(df["time_study"])]
# Out:
#     number_courses  time_study   Marks
# 80               7       7.957  54.321

# %%
df[(df["Marks"] > 10) & (df["number_courses"] == 3)]
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 6                3       6.063  29.889
# 9                3       6.173  30.862
# 10               3       7.353  42.036
# 13               3       4.274  17.672
# 14               3       2.908  11.397
# 34               3       4.083  17.171
# 35               3       7.543  43.978
# 48               3       5.635  26.882
# 58               3       6.198  31.236
# 63               3       4.869  21.379
# 72               3       4.633  20.398
# 99               3       6.335  32.357

# %%
X = df[["number_courses","Marks"]] # independent varibales
y = df["time_study"] # dependent varialbe

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=51, test_size = 0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80, 2)
# (20, 2)
# (80,)
# (20,)

# %%
X_train
# Out:
#     number_courses   Marks
# 65               6  13.562
# 12               7  24.318
# 32               8  15.038
# 82               4  44.099
# 66               4  27.569
# ..             ...     ...
# 16               5  30.548
# 69               6  21.400
# 73               3   7.014
# 96               3   5.609
# 57               7  51.583
#
# [80 rows x 2 columns]

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train =  sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (80, 2)

# %%
X_train
# Out:
# array([[ 0.3907019 , -0.78660633],
#        [ 0.94884747, -0.00313668],
#        [ 1.50699304, -0.67909413],
#        [-0.72558924,  1.43771616],
#        [-0.72558924,  0.23366695],
#        [-1.28373482, -0.94430546],
#        [ 1.50699304, -0.48482921],
#        [ 1.50699304, -0.3494192 ],
#        [-0.72558924, -0.35655754],
#        [-0.72558924,  1.13564767],
#        [ 0.3907019 , -0.34752535],
#        [ 1.50699304,  0.00655107],
#        [-1.28373482,  0.47352986],
#        [ 0.3907019 , -0.38117754],
#        [ 0.94884747, -0.85325515],
#        [-1.28373482, -1.33356371],
#        [-0.72558924, -0.16666303],
#        [-0.72558924, -1.13077648],
#        [-1.28373482, -1.18445974],
#        [-0.72558924, -0.56488063],
#        [ 0.94884747, -0.08828693],
#        [ 0.3907019 ,  1.18299383],
#        [ 0.3907019 , -0.62905289],
#        [-0.16744367,  0.90212185],
#        [ 0.94884747, -0.85733421],
#        [ 1.50699304,  1.31585443],
#        [ 1.50699304,  1.13601187],
# ...

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([X_test[2]])
# Out:
# array([1.43532692])

# %%
model.score(X_test,y_test) # r square
# Out:
# 0.9293084493511263

# %%
y_predict = model.predict(X_test)

# %%
# Mean Square Error
mse = mean_squared_error(y_test,y_predict)
# Root mean Square error
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.6330712469572819
